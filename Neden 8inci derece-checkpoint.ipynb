# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
veri = pd.read_csv("dolaralis.csv")
x = veri["Gun"]
y = veri["Fiyat"]
x = x.values.reshape(251,1)
y= y.values.reshape(251,1)


hatakaresipolinom = 0
    
for a in range(150):
    tahminpolinom = PolynomialFeatures(degree=a+1)
    Xyeni = tahminpolinom.fit_transform(x)
    polinommodel = LinearRegression()
    polinommodel.fit(Xyeni,y)
    polinommodel.predict(Xyeni)
    for i in range(len(Xyeni)):
        hatakaresipolinom = hatakaresipolinom + (float(y[i])-float(polinommodel.predict(Xyeni)[i]))**2
    print(a+1,"inci dereceden fonksiyonda hata,", hatakaresipolinom)
    hatakaresipolinom = 0
# Out:
# 1 inci dereceden fonksiyonda hata, 4.480811679650133
# 2 inci dereceden fonksiyonda hata, 1.0022083935828165
# 3 inci dereceden fonksiyonda hata, 0.7993121115038687
# 4 inci dereceden fonksiyonda hata, 0.6705321947556301
# 5 inci dereceden fonksiyonda hata, 0.6672058203663923
# 6 inci dereceden fonksiyonda hata, 0.3863062355441823
# 7 inci dereceden fonksiyonda hata, 0.382333725303265
# 8 inci dereceden fonksiyonda hata, 0.3815800225076998
# 9 inci dereceden fonksiyonda hata, 0.4175267566283461
# 10 inci dereceden fonksiyonda hata, 0.49727660805158796
# 11 inci dereceden fonksiyonda hata, 0.6982974662568616
# 12 inci dereceden fonksiyonda hata, 0.6916005039599727
# 13 inci dereceden fonksiyonda hata, 0.6801543769851577
# 14 inci dereceden fonksiyonda hata, 0.6714592656816996
# 15 inci dereceden fonksiyonda hata, 0.6674050757603054
# 16 inci dereceden fonksiyonda hata, 0.6673739166124998
# 17 inci dereceden fonksiyonda hata, 0.6700292608641492
# 18 inci dereceden fonksiyonda hata, 0.674145845422298
# 19 inci dereceden fonksiyonda hata, 0.6788737465056983
# 20 inci dereceden fonksiyonda hata, 0.6837274025981773
# 21 inci dereceden fonksiyonda hata, 0.6884806906408684
# 22 inci dereceden fonksiyonda hata, 0.693059628283252
# 23 inci dereceden fonksiyonda hata, 0.6974653222416464
# 24 inci dereceden fonksiyonda hata, 0.7017293587030097
# 25 inci dereceden fonksiyonda hata, 0.7058941645144637
# 26 inci dereceden fonksiyonda hata, 0.7099989893192435
# 27 inci dereceden fonksiyonda hata, 0.7140984734319501
# 28 inci dereceden fonksiyonda hata, 0.7182220932433485
# 29 inci dereceden fonksiyonda hata, 0.7224255450445345
# 30 inci dereceden fonksiyonda hata, 0.7267616141144523
# 31 inci dereceden fonksiyonda hata, 0.7314140485264068
# 32 inci dereceden fonksiyonda hata, 0.7361009547436569
# 33 inci dereceden fonksiyonda hata, 0.7411109299796693
# 34 inci dereceden fonksiyonda hata, 0.7464760244334473
# 35 inci dereceden fonksiyonda hata, 1.2461693913235519
# 36 inci dereceden fonksiyonda hata, 0.7913359712492278
# 37 inci dereceden fonksiyonda hata, 0.8031530496110774
# 38 inci dereceden fonksiyonda hata, 0.8437188210175507
# 39 inci dereceden fonksiyonda hata, 0.8646161428779687
# 40 inci dereceden fonksiyonda hata, 0.8775618456888072
# 94 inci dereceden fonksiyonda hata, 6.017937645769311
# 95 inci dereceden fonksiyonda hata, 3.7350816669286098
# 96 inci dereceden fonksiyonda hata, 7.536520945191588
# 97 inci dereceden fonksiyonda hata, 4.273955080903812
# 98 inci dereceden fonksiyonda hata, 3.8586474744155703
# 99 inci dereceden fonksiyonda hata, 3.903300612770626
# 100 inci dereceden fonksiyonda hata, 4.169710372018496
# 101 inci dereceden fonksiyonda hata, 4.038683521574072
# 102 inci dereceden fonksiyonda hata, 4.032084155459495
# 103 inci dereceden fonksiyonda hata, 4.72876696751835
# 104 inci dereceden fonksiyonda hata, 4.099627497255282
# 105 inci dereceden fonksiyonda hata, 4.422888858845229
# 106 inci dereceden fonksiyonda hata, 4.1771663634112635
# 107 inci dereceden fonksiyonda hata, 4.203195120288419
# 108 inci dereceden fonksiyonda hata, 5.424068629222291
# 109 inci dereceden fonksiyonda hata, 4.273061233793659
# 110 inci dereceden fonksiyonda hata, 4.308458892176806
# 111 inci dereceden fonksiyonda hata, 4.341042160267467
# 112 inci dereceden fonksiyonda hata, 4.389792323389245
# 113 inci dereceden fonksiyonda hata, 5.285882221382752
# 114 inci dereceden fonksiyonda hata, 4.453621144033725
# 115 inci dereceden fonksiyonda hata, 4.5436833962079675
# 116 inci dereceden fonksiyonda hata, 4.545771231513609
# 117 inci dereceden fonksiyonda hata, 4.610422521626114
# 118 inci dereceden fonksiyonda hata, 4.563861777864312
# 119 inci dereceden fonksiyonda hata, 4.890104038980522
# 120 inci dereceden fonksiyonda hata, 4.627552049262233
# 121 inci dereceden fonksiyonda hata, 5.320978533342021
# 122 inci dereceden fonksiyonda hata, 7.803431561343079
# 123 inci dereceden fonksiyonda hata, 4.834434766975372
# 124 inci dereceden fonksiyonda hata, 4.7464446841561765
# 125 inci dereceden fonksiyonda hata, 4.763210816421758
# 126 inci dereceden fonksiyonda hata, 6.909824116627945
# 127 inci dereceden fonksiyonda hata, 4.8233028919984005
# 128 inci dereceden fonksiyonda hata, 5.637071656231733
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\numpy\core\_methods.py:35: RuntimeWarning: overflow encountered in reduce
#   return umr_prod(a, axis, dtype, out, keepdims)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\numpy\core\_methods.py:32: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-bcbae0bfea47> in <module>()
#      17     Xyeni = tahminpolinom.fit_transform(x)
#      18     polinommodel = LinearRegression()
# ---> 19     polinommodel.fit(Xyeni,y)
#      20     polinommodel.predict(Xyeni)
#      21     for i in range(len(Xyeni)):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     451                              % (array.ndim, estimator_name))
#     452         if force_all_finite:
# --> 453             _assert_all_finite(array)
#     454
#     455     shape_repr = _shape_repr(array.shape)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X)
#      42             and not np.isfinite(X).all()):
#      43         raise ValueError("Input contains NaN, infinity"
# ---> 44                          " or a value too large for %r." % X.dtype)
#      45
#      46
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
